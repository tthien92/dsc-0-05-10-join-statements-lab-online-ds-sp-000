# %% [markdown]
# # Join Statements

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on Join statements.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
import pandas as pd
con = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = con.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
cur.execute("""select * from offices
                        join employees
                        using(officeCode);
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
boston_employee = df.loc[df.city == 'Boston']
boston_employee.loc[: ,['firstName','lastName']]
# Out:
#   firstName   lastName
# 6     Julie   Firrelli
# 7     Steve  Patterson

# %% [markdown]
# ## Do any offices have no employees?

# %%
cur.execute("""select * from offices
                        join employees
                        using(officeCode);
                       """)
df = pd.DataFrame(cur.fetchall()) 
df.columns = [i[0] for i in cur.description]
df[df.lastName.isnull()].head()
# Out:
# Empty DataFrame
# Columns: [officeCode, city, phone, addressLine1, addressLine2, state, country, postalCode, territory, employeeNumber, lastName, firstName, extension, email, reportsTo, jobTitle]
# Index: []

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
cur.execute("""select * from payments
                        join customers using(customerNumber)
                        join orders using (customerNumber);
                       """)
df = pd.DataFrame(cur.fetchall()) 
df.columns = [i[0] for i in cur.description]
same_day_df = df.loc[df.orderDate == df.paymentDate]
df.head()
#who paid the same day they ordered?
# Out:
#   customerNumber checkNumber paymentDate    amount       customerName  \
# 0            103    HQ336336  2004-10-19   6066.78  Atelier graphique
# 1            103    HQ336336  2004-10-19   6066.78  Atelier graphique
# 2            103    HQ336336  2004-10-19   6066.78  Atelier graphique
# 3            103    JM555205  2003-06-05  14571.44  Atelier graphique
# 4            103    JM555205  2003-06-05  14571.44  Atelier graphique
#
#   contactLastName contactFirstName       phone    addressLine1 addressLine2  \
# 0         Schmitt          Carine   40.32.2555  54, rue Royale
# 1         Schmitt          Carine   40.32.2555  54, rue Royale
# 2         Schmitt          Carine   40.32.2555  54, rue Royale
# 3         Schmitt          Carine   40.32.2555  54, rue Royale
# 4         Schmitt          Carine   40.32.2555  54, rue Royale
#
#     ...    postalCode country salesRepEmployeeNumber creditLimit orderNumber  \
# 0   ...         44000  France                   1370    21000.00       10123
# 1   ...         44000  France                   1370    21000.00       10298
# 2   ...         44000  France                   1370    21000.00       10345
# 3   ...         44000  France                   1370    21000.00       10123
# 4   ...         44000  France                   1370    21000.00       10298
#
#     orderDate requiredDate shippedDate   status comments
# 0  2003-05-20   2003-05-29  2003-05-22  Shipped
# 1  2004-09-27   2004-10-05  2004-10-01  Shipped
# 2  2004-11-25   2004-12-01  2004-11-26  Shipped
# 3  2003-05-20   2003-05-29  2003-05-22  Shipped
# 4  2004-09-27   2004-10-05  2004-10-01  Shipped
#
# [5 rows x 22 columns]

# %%
cur.execute('''SELECT orderNumber FROM orders WHERE orderDate = shippedDate;''').fetchall()
#tried to see if any order shipped the same day. Apparently not?
# Out:
# []

# %%
cur.execute("""select * from payments
                        join customers using(customerNumber);
                       """)
df = pd.DataFrame(cur.fetchall()) 
df.columns = [i[0] for i in cur.description]
over_df = df.loc[df.amount.sum() > df.creditLimit]
over_df
#list of customers who made payments that exceeded their credit limits
# Out:
#     customerNumber checkNumber paymentDate     amount  \
# 0              103    HQ336336  2004-10-19    6066.78
# 1              103    JM555205  2003-06-05   14571.44
# 2              103    OM314933  2004-12-18    1676.14
# 6              114     GG31455  2003-05-20   45864.03
# 7              114    MA765515  2004-12-15   82261.22
# 8              114    NP603840  2003-05-31    7565.08
# 9              114     NR27552  2004-03-10   44894.74
# 10             119    DB933704  2004-11-14   19501.82
# 11             119    LN373447  2004-08-08   47924.19
# 212      Charleroi               B-6000      Belgium                   1401
# 219  Reggio Emilia                42100        Italy                   1401
# 220  Reggio Emilia                42100        Italy                   1401
# 234       Glendale        CT      97561          USA                   1323
# 235       Glendale        CT      97561          USA                   1323
# 236       Glendale        CT      97561          USA                   1323
# 237         Bräcke             S-844 67       Sweden                   1504
# 238         Bräcke             S-844 67       Sweden                   1504
# 240           Graz                 8010      Austria                   1401
# 241           Graz                 8010      Austria                   1401
# 242           Graz                 8010      Austria                   1401
# 245            NYC        NY      10022          USA                   1286
# 246            NYC        NY      10022          USA                   1286
# 247         Madrid                28023        Spain                   1702
# 248         Madrid                28023        Spain                   1702
# 249         Madrid                28023        Spain                   1702
# 253   Glen Waverly  Victoria       3150    Australia                   1611
# 254   Glen Waverly  Victoria       3150    Australia                   1611
# 255          Milan                             Italy                   1401
# 256          Milan                             Italy                   1401
# 257        Burbank        CA      94019          USA                   1166
# 258        Burbank        CA      94019          USA                   1166
# 264       Brisbane        CA      94217          USA                   1165
# 265       Brisbane        CA      94217          USA                   1165
# 266         London              WA1 1DP           UK                   1501
# 267         London              WA1 1DP           UK                   1501
# 270     Auckland                         New Zealand                   1612
# 271     Auckland                         New Zealand                   1612
# 272     Auckland                         New Zealand                   1612
#
#     creditLimit
# 0      21000.00
# 1      21000.00
# 2      21000.00
# 6     117300.00
# 7     117300.00
# 8     117300.00
# 9     117300.00
# 10    118200.00
# 11    118200.00
# 12    118200.00
# 17    210500.00
# 18    210500.00
# 19    210500.00
# 20    210500.00
# 21    210500.00
# 22    210500.00
# 23    210500.00
# 24    210500.00
# 25    210500.00
# 26     59700.00
# 27     59700.00
# 28     59700.00
# 29     59700.00
# 33    114900.00
# 34    114900.00
# 35    114900.00
# 36    227600.00
# 37    227600.00
# 38    227600.00
# 39    227600.00
# ..          ...
# 211    23500.00
# 212    23500.00
# 219   121400.00
# 220   121400.00
# 234    49700.00
# 235    49700.00
# 236    49700.00
# 237   116400.00
# 238   116400.00
# 240    45300.00
# 241    45300.00
# 242    45300.00
# 245    39800.00
# 246    39800.00
# 247   104600.00
# 248   104600.00
# 249   104600.00
# 253    60300.00
# 254    60300.00
# 255    34800.00
# 256    34800.00
# 257    55400.00
# 258    55400.00
# 264    60300.00
# 265    60300.00
# 266    43300.00
# 267    43300.00
# 270   110000.00
# 271   110000.00
# 272   110000.00
#
# [142 rows x 16 columns]

# %%
cur.execute('''SELECT DISTINCT customerName FROM offices, customers WHERE customers.city = 'Boston' and offices.city = 'Boston'; ''').fetchall()
#only two companies shop in Boston as their home city
# Out:
# [('Diecast Collectables',), ('Gifts4AllAges.com',)]

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
cur.execute("""SELECT * from employees e
                JOIN customers c
                ON employeeNumber = c.salesRepEmployeeNumber
                JOIN orders USING (customerNumber)
                JOIN orderdetails USING(orderNumber)
                JOIN products USING (productCode);
                """)
orders_df = pd.DataFrame(cur.fetchall())
orders_df.columns = [i[0] for i in cur.description]
#df_full = (orders_df.firstName + " " + orders_df.lastName).unique()
df1 = orders_df('firstName lastName productName'))]
df1.head()
df1 = df[['b', 'c']]
#|example.setdefault('a', []).append('apple')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-32-7f79234459e4> in <module>()
# ----> 1 str('Leslie').isin('Leslie Jennings')
#
# AttributeError: 'str' object has no attribute 'isin'

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
